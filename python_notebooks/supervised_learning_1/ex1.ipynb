# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
house_votes = pd.read_csv("house-votes-84.csv", header = None, na_values = ["", " ", "?"])

# %%
col_nms = ["party", "handicapped_infants", "water_proj_cost_share", 
            "budget_sol_adopt", "physician_fee", "elsavaldor_aid", "religious_groups_school", "anti_satellite",
           "aid_nicaraguan", "mx_missile", "immigration", ". synfuels_corporation_cutback",
           "education_spending", "superfund_right", "crime", "duty_free_exports", 
            "export_administration_south_africa"]

house_votes.columns = col_nms 

house_votes.head()
# Out:
#         party handicapped_infants water_proj_cost_share budget_sol_adopt  \
# 0  republican                   n                     y                n
# 1  republican                   n                     y                n
# 2    democrat                 NaN                     y                y
# 3    democrat                   n                     y                y
# 4    democrat                   y                     y                y
#
#   physician_fee elsavaldor_aid religious_groups_school anti_satellite  \
# 0             y              y                       y              n
# 1             y              y                       y              n
# 2           NaN              y                       y              n
# 3             n            NaN                       y              n
# 4             n              y                       y              n
#
#   aid_nicaraguan mx_missile immigration . synfuels_corporation_cutback  \
# ...

# %%
grouped_df = house_votes.groupby("party",  group_keys=True).count()
grouped_df
# Out:
#             handicapped_infants  water_proj_cost_share  budget_sol_adopt  \
# party
# democrat                    258                    239               260
# republican                  165                    148               164
#
#             physician_fee  elsavaldor_aid  religious_groups_school  \
# party
# democrat              259             255                      258
# republican            165             165                      166
#
#             anti_satellite  aid_nicaraguan  mx_missile  immigration  \
# party
# democrat               259             263         248          263
# republican             162             157         165          165
#
#             . synfuels_corporation_cutback  education_spending  \
# party
# democrat                               255                 249
# republican                             159                 155
#
#             superfund_right  crime  duty_free_exports  \
# party
# ...
